# %%
from tensorflow.keras.datasets import mnist

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images.shape
# Out:
# (10000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
from tensorflow import keras
from tensorflow.keras import layers
model = keras.Sequential([
 layers.Dense(512, activation="relu"),
 layers.Dense(10, activation="softmax")
])

# %%
model.compile(optimizer="rmsprop",
 loss="sparse_categorical_crossentropy",
 metrics=["accuracy"])

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2548 - accuracy: 0.9260
# Epoch 2/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1041 - accuracy: 0.9690
# Epoch 3/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0695 - accuracy: 0.9791
# Epoch 4/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0500 - accuracy: 0.9852
# Epoch 5/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0381 - accuracy: 0.9887

# %%
test_digits = test_images[0:10]
predictions = model.predict(test_digits)
predictions[0]
# Out:
# 1/1 [==============================] - 0s 57ms/step
# array([5.0441336e-09, 2.3330053e-09, 5.5278724e-06, 6.2911672e-04,
#        1.1369139e-13, 8.0374171e-08, 1.2192800e-12, 9.9936467e-01,
#        3.9968421e-07, 1.9311915e-07], dtype=float32)

# %%
predictions[0].argmax()
# Out:
# 7

# %%
predictions[0][7]
# Out:
# 0.9993647

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"test_acc: {test_acc}")
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0646 - accuracy: 0.9800
# test_acc: 0.9800000190734863
